# %% [markdown]
# # 11 - GANs: Basic Generative Models
#
# Objective: Implement a simple DCGAN on MNIST to illustrate generator and discriminator training loops and common stability tips.
#
# Suggested dataset: MNIST.
#
# Deliverable: saved sample generator outputs and notes on training stability.

# %%
import numpy as np
import torch
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
