# %% [markdown]
# # 04 - Ensemble Methods
#
# Objective: Demonstrate bagging, random forest, and boosting (XGBoost/LightGBM) with comparisons.
#
# Suggested dataset: structured classification/regression (Adult/Wine).
#
# Deliverable: comparison table of performance and feature importances.

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
SEED = 42
np.random.seed(SEED)
