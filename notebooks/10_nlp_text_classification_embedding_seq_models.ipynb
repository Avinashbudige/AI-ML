# %% [markdown]
# # 10 - NLP: Text Classification, Embeddings & Sequence Models
#
# Objective: Tokenization + TF-IDF + linear classifier; demo embeddings and a small LSTM/Transformer example.
#
# Suggested dataset: IMDB or AG News.
#
# Deliverable: comparison of models and an inference pipeline example.

# %%
import numpy as np
import torch
from sklearn.feature_extraction.text import TfidfVectorizer
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
