# %% [markdown]
# # 09 - Computer Vision: Classification & (Intro) Object Detection
#
# Objective: Train a CNN for classification and demonstrate transfer learning (e.g., ResNet). Optionally show an object detection example.
#
# Suggested dataset: CIFAR-10 or small Cats vs Dogs subset.
#
# Deliverable: accuracy, confusion matrix, and a sample Grad-CAM explanation.

# %%
import numpy as np
import torch
import torchvision
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
