# %% [markdown]
# # 06 - Model Selection & Hyperparameter Tuning
#
# Objective: Cross-validation strategies, grid/random search, and (optionally) Bayesian optimization.
#
# Suggested dataset: supervised dataset used earlier.
#
# Deliverable: tuned model and explanation of CV strategy.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
SEED = 42
np.random.seed(SEED)
