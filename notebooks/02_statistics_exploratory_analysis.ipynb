# %% [markdown]
# # 02 - Statistics & Exploratory Data Analysis
#
# Objective: Descriptive statistics, distributions, central tendency, hypothesis testing and confidence intervals.
#
# Suggested dataset: UCI Wine or Iris.
#
# Deliverable: report with tests (t-test, chi-square) and interpretations.

# %%
import numpy as np
import pandas as pd
from scipy import stats
SEED = 42
np.random.seed(SEED)
