# %% [markdown]
# # 03 - Supervised Learning Baseline Models
#
# Objective: Train baseline models (linear/logistic regression, decision tree) and report metrics.
#
# Suggested dataset: UCI Adult or Kaggle Titanic.
#
# Deliverable: baseline metrics and a short model card.

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
SEED = 42
np.random.seed(SEED)
