# %% [markdown]
# # 05 - Feature Engineering & Selection
#
# Objective: Encode categorical variables, scaling, interaction terms, and feature selection techniques (L1, recursive).
#
# Suggested dataset: any supervised dataset from earlier notebooks.
#
# Deliverable: before/after performance and selected features list.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, StandardScaler
SEED = 42
np.random.seed(SEED)
