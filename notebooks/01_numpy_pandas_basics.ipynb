# %% [markdown]
# # 01 - Numpy & Pandas Basics
#
# Objective: Demonstrate array operations, broadcasting, vectorization, groupby, joins, pivoting, and missing-data handling.
#
# Suggested dataset: small CSV (Titanic subset) or synthetic data.
#
# Deliverable: short script showing vectorized vs loop timing and a cleaned DataFrame.

# %%
import numpy as np
import pandas as pd
SEED = 42
np.random.seed(SEED)
