# %% [markdown]
# # 08 - Introduction to Neural Networks & Deep Learning
#
# Objective: Build and train a small MLP in PyTorch or TensorFlow; explain backpropagation, loss and optimizer choices.
#
# Suggested dataset: MNIST or Fashion-MNIST.
#
# Deliverable: training curve, saved model, and short explanation.

# %%
import numpy as np
import torch
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
