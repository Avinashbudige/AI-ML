# %% [markdown]
# # 07 - Unsupervised Learning: Clustering & Dimensionality Reduction
#
# Objective: KMeans, hierarchical clustering, DBSCAN; PCA/TSNE/UMAP visualizations.
#
# Suggested dataset: MNIST subset or Iris.
#
# Deliverable: cluster metrics and visualization plots.

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
SEED = 42
np.random.seed(SEED)
