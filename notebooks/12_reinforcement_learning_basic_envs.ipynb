# %% [markdown]
# # 12 - Reinforcement Learning: Basic Environments
#
# Objective: Implement a small RL demo (CartPole) using a simple DQN or policy gradient approach; visualize training.
#
# Suggested envs: OpenAI Gym CartPole, MountainCar.
#
# Deliverable: training curve and a rendered episode GIF or short video.

# %%
import numpy as np
SEED = 42
np.random.seed(SEED)
